# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import plotly.express as px
# Out:
# 2022-05-16 09:09:58.523167: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-16 09:09:58.523210: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from src.make_datasets import create_dataset, ts_train_test_split
from src.make_LSTM_model import fit_LSTM_type1, fit_LSTM_type2, evaluate_model
from src.visualization import mlp_learnig_curve_plot, test_predicted_plot
from src.trade_simulation import trade_on_pred

# %%
df_ILSIRS_curve = pd.read_csv('./data/ILSIRS_AM3T_data.csv',parse_dates=['Date'])

# %%
df_ILSIRS_curve['Date'].duplicated().sum()
# Out:
# 0

# %%
target='ILS10Y'
cols=['Date',target]
ts1=df_ILSIRS_curve[cols]
ts1=ts1.set_index('Date').sort_index(ascending=True)
start_date ,end_date = '2011-12-19','2022-05-11'
ts1=ts1[start_date:end_date]
ts1
# Out:
#             ILS10Y
# Date
# 2011-12-19   4.230
# 2011-12-20   4.240
# 2011-12-21   4.240
# 2011-12-22   4.210
# 2011-12-23   4.210
# ...            ...
# 2022-05-04   2.445
# 2022-05-06   2.530
# 2022-05-09   2.665
# 2022-05-10   2.695
# 2022-05-11   2.725
#
# [2528 rows x 1 columns]

# %%
ts1.isnull().sum()
# Out:
# ILS10Y    0
# dtype: int64

# %%
n_lag=1
lag_col='lag_'+str(n_lag)
ts1[lag_col]=ts1[target].shift(n_lag)

# %%
n_lag=2
sma2='SMA'+str(n_lag)
ts1[sma2] = ts1[target].rolling(n_lag,closed='left').mean()

# %%
n_lag=5
sma5='SMA'+str(n_lag)
ts1[sma5] = ts1[target].rolling(n_lag,closed='left').mean()

# %%
n_lag=10
sma10='SMA'+str(n_lag)
ts1[sma10] = ts1[target].rolling(n_lag,closed='left').mean()

# %%
train,test = ts_train_test_split(ts1,0.9)
print(len(train), len(test))
test
# Out:
# 2275 253
#             ILS10Y  lag_1    SMA2   SMA5   SMA10
# Date
# 2021-04-30   1.315  1.305  1.2925  1.247  1.2270
# 2021-05-03   1.290  1.315  1.3100  1.268  1.2390
# 2021-05-04   1.290  1.290  1.3025  1.285  1.2470
# 2021-05-05   1.315  1.290  1.2900  1.296  1.2550
# 2021-05-06   1.340  1.315  1.3025  1.303  1.2650
# ...            ...    ...     ...    ...     ...
# 2022-05-04   2.445  2.420  2.4175  2.391  2.3840
# 2022-05-06   2.530  2.445  2.4325  2.410  2.3915
# 2022-05-09   2.665  2.530  2.4875  2.441  2.4055
# 2022-05-10   2.695  2.665  2.5975  2.495  2.4315
# 2022-05-11   2.725  2.695  2.6800  2.551  2.4640
#
# [253 rows x 5 columns]

# %%
# baseline n_lag- pred on prev n_lag days
lag1_mae=mean_absolute_error(test[target], test['lag_1'])
print(f'MAE baseline - pred on lag_1 : {lag1_mae:.3f}')
# Out:
# MAE baseline - pred on lag_1 : 0.028

# %%
# baseline MAE- simple moving avarage w/ lag_2
sma2_mae=mean_absolute_error(test[target], test['SMA2'])
print(f'MAE baseline - pred on SMA{n_lag} : {sma2_mae:.3f}')
# Out:
# MAE baseline - pred on SMA10 : 0.033

# %%
# baseline MAE- simple moving avarage w/ lag_5
sma5_mae=mean_absolute_error(test[target], test['SMA5'])
print(f'MAE baseline for SMA{n_lag} : {sma5_mae:.3f}')
# Out:
# MAE baseline for SMA10 : 0.046

# %%
# baseline MAE- simple moving avarage w/ lag_10
sma10_mae=mean_absolute_error(test[target], test['SMA10'])
print(f'MAE baseline for SMA{n_lag} : {sma10_mae:.3f}')
# Out:
# MAE baseline for SMA10 : 0.065

# %%
fig = px.line(test,x=test.index,y=[target,sma2,sma5,sma10],
              title=f'ILS 10Y actual vs SMA pred- baseline')
fig.update_layout(legend_title=target, width=800,height=600)
fig.show()

# %%
mtm_lag1=trade_on_pred(test[target],test['lag_1'],lag1_mae)
mtm_ma2=trade_on_pred(test[target],test[sma2],sma2_mae)
mtm_ma5=trade_on_pred(test[target],test[sma5],sma5_mae)
mtm_ma10=trade_on_pred(test[target],test[sma10],sma10_mae)

print('Trade P&L results on test data w/ SMA pred:')
print(f'Baseline 0 - lag_1 pred : {mtm_lag1:.2f}')
print(f'Baseline 1 - {sma2}  pred : {mtm_ma2:.2f}')
print(f'Baseline 2 - {sma5}  pred : {mtm_ma5:.2f}')
print(f'Baseline 3 - {sma10} pred : {mtm_ma10:.2f}')
# Out:
# Trade P&L results on test data w/ SMA pred:
# Baseline 0 - lag_1 pred : -2.64
# Baseline 1 - SMA2  pred : -29.03
# Baseline 2 - SMA5  pred : -19.67
# Baseline 3 - SMA10 pred : 9.26

# %%
ts2=df_ILSIRS_curve[cols]
ts2=ts2.set_index('Date').sort_index(ascending=True)
start_date ,end_date = '2012-01-01','2022-05-11'
ts2=ts2[start_date:end_date]
ts2
# Out:
#             ILS10Y
# Date
# 2012-01-03   4.130
# 2012-01-04   4.110
# 2012-01-05   4.130
# 2012-01-06   4.130
# 2012-01-09   4.120
# ...            ...
# 2022-05-04   2.445
# 2022-05-06   2.530
# 2022-05-09   2.665
# 2022-05-10   2.695
# 2022-05-11   2.725
#
# [2518 rows x 1 columns]

# %%
train,test = ts_train_test_split(ts2,0.9)
print(len(train), len(test))
# Out:
# 2266 252

# %%
n_lag=10
n_features = 1

# %%
# reshape to [samples, n_steps, n_features]
X_train, y_train = create_dataset(train, train[target], n_lag)
X_test, y_test = create_dataset(test, test[target], n_lag)

print(f'X_train shape:{X_train.shape}  y_train shape:{y_train.shape}')
print(f'X_test  shape:{X_test.shape}   y_test  shape:{y_test.shape}')
# Out:
# X_train shape:(2256, 10, 1)  y_train shape:(2256,)
# X_test  shape:(242, 10, 1)   y_test  shape:(242,)

# %%
# early stopping
early_stopping_monitor = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=5,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

# %%
# define and fir the model
model, history=fit_LSTM_type1(
    X_train,y_train,X_test,y_test,n_lag,n_features,
    l1_neurons=8,
    batch_size=3,
    n_epochs=100,
    learning_rate=0.0001,
    verbose=0,
    callbacks=early_stopping_monitor
)
# Out:
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  first_layer (LSTM)          (None, 8)                 320
#
#  dense_8 (Dense)             (None, 1)                 9
#
# ...
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_dtype=False, show_shapes=True, show_layer_names=True)

# %%
# plot mlp learnig curve
title='MLP learing curve - Train vs Test MAE'
mlp_learnig_curve_plot(history,title).show()

# %%
# evaluate the model
train_mae, test_mae = evaluate_model(model, X_train, y_train, X_test, y_test, verbose=0)
print(f'Train MAE: {train_mae:.3f}, Test MAE: {test_mae:.3f}')
# Out:
# Train MAE: 0.150, Test MAE: 0.066

# %%
# test set - actual vs predicted plot
y_pred = model.predict(X_test)
title=f'{target} - actual vs predicted'
test_predicted_plot(y_pred, y_test, test.index[n_lag:], title,target).show()

# %%
mtm_nn_1=trade_on_pred(y_test,y_pred,test_mae)
print(f'Trade P&L : {mtm_nn_1:.2f}')
# Out:
# Trade P&L : -19.37

# %%
# pred on last n_lag days for 1 day in the future
model.predict(test.tail(n_lag).values.reshape(1,n_lag,n_features))
# Out:
# array([[2.5507991]], dtype=float32)

# %%
df_USDIRS_curve = pd.read_csv('./data/USDIRS_AM3L_data.csv',parse_dates=['Date']).dropna(how='any').set_index('Date')

# %%
df_USDIRS_curve
# Out:
#             USD1Y  USD2Y  USD3Y  USD4Y  USD5Y  USD6Y  USD7Y  USD8Y  USD9Y  \
# Date
# 2022-05-11  2.468  2.875  2.931  2.921  2.912  2.918  2.931  2.939  2.949
# 2022-05-10  2.406  2.833  2.901  2.902  2.901  2.913  2.932  2.944  2.955
# 2022-05-09  2.400  2.857  2.940  2.974  2.992  3.020  3.039  3.055  3.072
# 2022-05-06  2.479  2.954  3.032  3.052  3.055  3.071  3.081  3.090  3.104
# 2022-05-05  2.505  3.009  3.088  3.102  3.095  3.102  3.105  3.107  3.115
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2005-03-11  3.650  4.065  4.300  4.455  4.575  4.665  4.740  4.810  4.875
# 2005-03-10  3.630  4.025  4.255  4.405  4.535  4.625  4.710  4.780  4.850
# 2005-03-09  3.595  3.985  4.200  4.355  4.475  4.570  4.650  4.725  4.795
# 2005-03-08  3.580  3.965  4.165  4.300  4.410  4.495  4.570  4.640  4.700
# 2005-03-07  3.545  3.910  4.090  4.215  4.325  4.410  4.480  4.550  4.610
#
# ...

# %%
df_USDIRS_curve.isna().sum()
# Out:
# USD1Y     0
# USD2Y     0
# USD3Y     0
# USD4Y     0
# USD5Y     0
# USD6Y     0
# USD7Y     0
# USD8Y     0
# USD9Y     0
# USD10Y    0
# USD12Y    0
# USD15Y    0
# USD20Y    0
# USD25Y    0
# USD30Y    0
# USD40Y    0
# USD50Y    0
# dtype: int64

# %%
ts3=ts2.merge(df_USDIRS_curve['USD10Y'],how='left', on='Date').dropna(how='any')
ts3
# Out:
#             ILS10Y  USD10Y
# Date
# 2012-01-03   4.130   2.047
# 2012-01-04   4.110   2.100
# 2012-01-05   4.130   2.099
# 2012-01-06   4.130   2.053
# 2012-01-09   4.120   2.031
# ...            ...     ...
# 2022-05-04   2.445   3.024
# 2022-05-06   2.530   3.118
# 2022-05-09   2.665   3.088
# 2022-05-10   2.695   2.968
# 2022-05-11   2.725   2.961
#
# [2510 rows x 2 columns]

# %%
ts3.isnull().sum()
# Out:
# ILS10Y    0
# USD10Y    0
# dtype: int64

# %%
n_lag = 10
n_features = 2

# %%
train,test = ts_train_test_split(ts3,0.9)
print(len(train), len(test))
# Out:
# 2259 251

# %%
# reshape to [samples, n_lag, n_features]
X_train, y_train = create_dataset(train, train[target], n_lag)
X_test, y_test = create_dataset(test, test[target], n_lag)

print(f'X_train shape:{X_train.shape}  y_train shape:{y_train.shape}')
print(f'X_test  shape:{X_test.shape}   y_test  shape:{y_test.shape}')
# Out:
# X_train shape:(2249, 10, 2)  y_train shape:(2249,)
# X_test  shape:(241, 10, 2)   y_test  shape:(241,)

# %%
# define model
model, history=fit_LSTM_type1(
    X_train,y_train,X_test,y_test,n_lag,n_features,
    l1_neurons=16,
    batch_size=3,
    n_epochs=100,
    learning_rate=0.0001,
    verbose=0,
    callbacks=early_stopping_monitor
)
# Out:
# Restoring model weights from the end of the best epoch: 13.
# Epoch 18: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  first_layer (LSTM)          (None, 16)                1216
#
#  dense_16 (Dense)            (None, 1)                 17
#
# ...
# Total params: 1,233
# Trainable params: 1,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_dtype=False, show_shapes=True, show_layer_names=True)

# %%
# plot mlp learnig curve
title='MLP learing curve - Train vs Test MAE'
mlp_learnig_curve_plot(history,title).show()

# %%
# evaluate the model
train_mae, test_mae = evaluate_model(model, X_train, y_train, X_test, y_test, verbose=0)
print(f'Train MAE: {train_mae:.3f}, Test MAE: {test_mae:.3f}')
# Out:
# Train MAE: 0.159, Test MAE: 0.082

# %%
# test set - actual vs predicted plot
y_pred = model.predict(X_test)
title=f'{target} - actual vs predicted w/ USD10Y as feature'
test_predicted_plot(y_pred, y_test, test.index[n_lag:], title,target).show()

# %%
mtm_nn_2=trade_on_pred(y_test,y_pred,test_mae)
print(f'Trade P&L : {mtm_nn_2:.2f}')
# Out:
# Trade P&L : -112.77

# %%
# pred on last n_steps days for tomorow pred
model.predict(test.tail(n_lag).values.reshape(1,n_lag,n_features))
# Out:
# array([[2.5599196]], dtype=float32)

# %%
df_SPXTR = pd.read_csv('./data/SPXTR.csv',parse_dates=['Date']).dropna(how='any').set_index('Date').sort_index(ascending=True)
df_SPXTR
# Out:
#                 SPXTR
# Date
# 2005-01-03  1784.9561
# 2005-01-04  1764.3025
# 2005-01-05  1758.0673
# 2005-01-06  1764.6263
# 2005-01-07  1762.1230
# ...               ...
# 2022-05-05  8729.2112
# 2022-05-06  8680.9666
# 2022-05-09  8403.4963
# 2022-05-10  8424.1959
# 2022-05-11  8285.8187
#
# [4370 rows x 1 columns]

# %%
df_SPXTR['SP_yield']=df_SPXTR.SPXTR.pct_change()
df_SPXTR
# Out:
#                 SPXTR  SP_yield
# Date
# 2005-01-03  1784.9561       NaN
# 2005-01-04  1764.3025 -0.011571
# 2005-01-05  1758.0673 -0.003534
# 2005-01-06  1764.6263  0.003731
# 2005-01-07  1762.1230 -0.001419
# ...               ...       ...
# 2022-05-05  8729.2112 -0.035543
# 2022-05-06  8680.9666 -0.005527
# 2022-05-09  8403.4963 -0.031963
# 2022-05-10  8424.1959  0.002463
# 2022-05-11  8285.8187 -0.016426
#
# [4370 rows x 2 columns]

# %%
ts4=ts3.merge(df_SPXTR['SP_yield'],how='left', on='Date').dropna(how='any')
ts4
# Out:
#             ILS10Y  USD10Y  SP_yield
# Date
# 2012-01-03   4.130   2.047  0.015499
# 2012-01-04   4.110   2.100  0.000400
# 2012-01-05   4.130   2.099  0.002944
# 2012-01-06   4.130   2.053 -0.002159
# 2012-01-09   4.120   2.031  0.002286
# ...            ...     ...       ...
# 2022-05-04   2.445   3.024  0.029874
# 2022-05-06   2.530   3.118 -0.005527
# 2022-05-09   2.665   3.088 -0.031963
# 2022-05-10   2.695   2.968  0.002463
# 2022-05-11   2.725   2.961 -0.016426
#
# [2449 rows x 3 columns]

# %%
ts4.isnull().sum()
# Out:
# ILS10Y      0
# USD10Y      0
# SP_yield    0
# dtype: int64

# %%
n_lag = 10
n_features = 3

# %%
train,test = ts_train_test_split(ts4,0.9)
print(len(train), len(test))
# Out:
# 2204 245

# %%
train=train.copy()
test=test.copy()
# fit scaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(train['SP_yield'].values.reshape(-1,1))
# transform train
train['SP_yield_sc']=pd.Series(scaler.transform(train['SP_yield'].values.reshape(-1,1)).reshape(-1), index=train.index)
train=train.drop('SP_yield',axis=1)

# transform test
test['SP_yield_sc']=pd.Series(scaler.transform(test['SP_yield'].values.reshape(-1,1)).reshape(-1), index=test.index)
test=test.drop('SP_yield',axis=1)

# %%
# reshape to [samples, time_steps, n_features]
X_train, y_train = create_dataset(train, train[target], n_lag)
X_test, y_test = create_dataset(test, test[target], n_lag)

print(f'X_train shape:{X_train.shape}  y_train shape:{y_train.shape}')
print(f'X_test  shape:{X_test.shape}   y_test  shape:{y_test.shape}')
# Out:
# X_train shape:(2194, 10, 3)  y_train shape:(2194,)
# X_test  shape:(235, 10, 3)   y_test  shape:(235,)

# %%
# define and fit the model 
model, history=fit_LSTM_type1(
    X_train,y_train,X_test,y_test,n_lag,n_features,
    l1_neurons=16,
    batch_size=3,
    n_epochs=100,
    learning_rate=0.0001,
    verbose=0,
    callbacks=early_stopping_monitor
)
# Out:
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  first_layer (LSTM)          (None, 16)                1280
#
#  dense_21 (Dense)            (None, 1)                 17
#
# ...
# Total params: 1,297
# Trainable params: 1,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_dtype=False, show_shapes=True, show_layer_names=True)

# %%
# plot mlp learnig curve
title='MLP learing curve - Train vs Test MAE'
mlp_learnig_curve_plot(history,title).show()

# %%
# evaluate the model
train_mae = model.evaluate(X_train, y_train, verbose=0)[1]
test_mae = model.evaluate(X_test, y_test, verbose=0)[1]
print(f'Train MAE: {train_mae:.3f}, Test MAE: {test_mae:.3f}')
# Out:
# Train MAE: 0.146, Test MAE: 0.093

# %%
# test set - actual vs predicted plot
y_pred = model.predict(X_test)
title=f'{target} - actual vs predicted w/ USD10Y and S&P500 as feauters'
test_predicted_plot(y_pred, y_test, test.index[n_lag:], title,target).show()

# %%
mtm_nn_3=trade_on_pred(y_test,y_pred,test_mae)
print(f'Trade P&L : {mtm_nn_3:.2f}')
# Out:
# Trade P&L : -109.59

# %%
# pred on last n_lag days for tomorow pred
model.predict(test.tail(n_lag).values.reshape(1,n_lag,n_features))
# Out:
# array([[2.4910877]], dtype=float32)

# %%
n_lag = 10
n_features = 13

# %%
drop_cols=['ILS25Y','ILS30Y']
cols=[col for col in df_ILSIRS_curve.columns if col not in drop_cols]
ts5=df_ILSIRS_curve[cols].set_index('Date').sort_index(ascending=True)
ts5=ts5[start_date:end_date]
ts5
# Out:
#             ILS1Y  ILS2Y  ILS3Y  ILS4Y  ILS5Y  ILS6Y  ILS7Y  ILS8Y  ILS9Y  \
# Date
# 2012-01-03  2.340  2.440  2.610  2.830  3.100  3.380  3.660  3.840  4.000
# 2012-01-04  2.330  2.410  2.570  2.800  3.070  3.350  3.630  3.830  3.980
# 2012-01-05  2.330  2.410  2.570  2.800  3.070  3.360  3.640  3.840  4.000
# 2012-01-06  2.340  2.430  2.590  2.810  3.080  3.360  3.640  3.840  4.000
# 2012-01-09  2.360  2.440  2.600  2.810  3.070  3.350  3.630  3.830  3.990
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2022-05-04  1.435  1.950  2.120  2.175  2.220  2.265  2.315  2.370  2.420
# 2022-05-06  1.485  2.025  2.195  2.255  2.305  2.355  2.405  2.455  2.505
# 2022-05-09  1.555  2.105  2.280  2.345  2.405  2.465  2.525  2.585  2.640
# 2022-05-10  1.585  2.140  2.310  2.375  2.435  2.495  2.555  2.615  2.670
# 2022-05-11  1.635  2.195  2.360  2.425  2.485  2.540  2.590  2.645  2.700
#
#             ILS10Y  ILS12Y  ILS15Y  ILS20Y
# Date
# ...

# %%
train,test = ts_train_test_split(ts5,0.9)
print(len(train), len(test))
# Out:
# 2266 252

# %%
ts5.isna().sum()
# Out:
# ILS1Y     0
# ILS2Y     0
# ILS3Y     0
# ILS4Y     0
# ILS5Y     0
# ILS6Y     0
# ILS7Y     0
# ILS8Y     0
# ILS9Y     0
# ILS10Y    0
# ILS12Y    0
# ILS15Y    0
# ILS20Y    0
# dtype: int64

# %%
# reshape to [samples, time_steps, n_features]
X_train, y_train = create_dataset(train, train[target], n_lag)
X_test, y_test = create_dataset(test, test[target], n_lag)

print(f'X_train shape:{X_train.shape}  y_train shape:{y_train.shape}')
print(f'X_test  shape:{X_test.shape}   y_test  shape:{y_test.shape}')
# Out:
# X_train shape:(2256, 10, 13)  y_train shape:(2256,)
# X_test  shape:(242, 10, 13)   y_test  shape:(242,)

# %%
# define and fit the model 
model, history=fit_LSTM_type1(
    X_train,y_train,X_test,y_test,n_steps,n_features,
    l1_neurons=32,
    batch_size=3,
    n_epochs=200,
    learning_rate=0.0001,
    verbose=0,
    callbacks=early_stopping_monitor
)
# Out:
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  first_layer (LSTM)          (None, 32)                5888
#
#  dense_27 (Dense)            (None, 1)                 33
#
# ...
# Total params: 5,921
# Trainable params: 5,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_dtype=False, show_shapes=True, show_layer_names=True)

# %%
# plot mlp learnig curve
title='MLP learing curve - Train vs Test MAE'
mlp_learnig_curve_plot(history,title).show()

# %%
# evaluate the model
train_mae = model.evaluate(X_train, y_train, verbose=0)[1]
test_mae = model.evaluate(X_test, y_test, verbose=0)[1]
print(f'Train MAE: {train_mae:.3f}, Test MAE: {test_mae:.3f}')
# Out:
# Train MAE: 0.253, Test MAE: 0.045

# %%
# test set - actual vs predicted plot
y_pred = model.predict(X_test)
title=f'{target} - actual vs predicted w/ all the ILS curve as features'
test_predicted_plot(y_pred, y_test, test.index[n_steps:], title,target).show()

# %%
# pred on last n_steps days for 1 day in the future
model.predict(test.tail(n_steps).values.reshape(1,n_lag,n_features))
# Out:
# array([[2.6161385]], dtype=float32)

# %%
mtm_nn_4=trade_on_pred(y_test,y_pred,test_mae)
print(f'Trade P&L : {mtm_nn_4:.2f}')
# Out:
# Trade P&L : 49.59
